# %%
import pandas as pd
import numpy as np
import seaborn as sns

from sklearn import linear_model
from sklearn.model_selection import cross_val_score
from sklearn.decomposition import PCA

# %%
raw = pd.read_csv('data/Melbourne_housing_FULL.csv')
raw_less = pd.read_csv('data/MELBOURNE_HOUSE_PRICES_LESS.csv')

raw.dropna(inplace = True)
raw.reset_index(inplace = True)

raw_less.dropna()

raw.tail()
# Out:
#       index      Suburb           Address  Rooms Type      Price Method  \
# 8882  34847     Wollert   27 Birchmore Rd      3    h   500000.0     PI
# 8883  34849     Wollert   35 Kingscote Wy      3    h   570000.0     SP
# 8884  34853  Yarraville     29A Murray St      2    h   888000.0     SP
# 8885  34854  Yarraville    147A Severn St      2    t   705000.0      S
# 8886  34856  Yarraville  3 Tarrengower St      2    h  1020000.0     PI
#
#       SellerG        Date  Distance  ...  Bathroom  Car  Landsize  \
# 8882      Ray  24/02/2018      25.5  ...       2.0  2.0     383.0
# 8883       RW  24/02/2018      25.5  ...       2.0  2.0     404.0
# 8884  Sweeney  24/02/2018       6.3  ...       2.0  1.0      98.0
# 8885      Jas  24/02/2018       6.3  ...       1.0  2.0     220.0
# 8886       RW  24/02/2018       6.3  ...       1.0  0.0     250.0
#
#       BuildingArea  YearBuilt               CouncilArea  Lattitude Longtitude  \
# ...

# %%
raw_less.head()
# Out:
#          Suburb           Address  Rooms Type      Price Method   SellerG  \
# 0    Abbotsford     49 Lithgow St      3    h  1490000.0      S    Jellis
# 1    Abbotsford     59A Turner St      3    h  1220000.0      S  Marshall
# 2    Abbotsford     119B Yarra St      3    h  1420000.0      S    Nelson
# 3    Aberfeldie        68 Vida St      3    h  1515000.0      S     Barry
# 4  Airport West  92 Clydesdale Rd      2    h   670000.0      S    Nelson
#
#         Date  Postcode             Regionname  Propertycount  Distance  \
# 0  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 1  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 2  1/04/2017      3067  Northern Metropolitan           4019       3.0
# 3  1/04/2017      3040   Western Metropolitan           1543       7.5
# 4  1/04/2017      3042   Western Metropolitan           3464      10.4
#
#                   CouncilArea
# 0          Yarra City Council
# 1          Yarra City Council
# ...

# %%
#raw_less.Suburb.unique()
print(raw.Regionname.unique())

print(raw.columns)
# Out:
# ['Northern Metropolitan' 'Western Metropolitan' 'Southern Metropolitan'
#  'Eastern Metropolitan' 'South-Eastern Metropolitan' 'Northern Victoria'
#  'Eastern Victoria' 'Western Victoria']
# Index(['index', 'Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method',
#        'SellerG', 'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom',
#        'Car', 'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea',
#        'Lattitude', 'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %% [markdown]
# __Options__
#
# We have been given latitude-longitude data as a part of the dataset. What we could do is use a clustering algorithm to group houses.

# %%
#Outcome, features
#Y = raw_less['Price'] / 1000
#X = raw_less[['Rooms']]
data = raw[['Rooms', 'Distance', 'Lattitude','Longtitude', 'Bedroom2', 'Bathroom', 'Car', 'BuildingArea', 'Price']]

Y = raw['Price']
X = raw[['Rooms', 'Distance', 'Lattitude','Longtitude', 'Bedroom2', 'Bathroom', 'Car', 'BuildingArea']]

for region in raw.Regionname.unique():
    data[str(region)] = np.where(raw['Regionname'] == region, 1, 0)
    X[str(region)] = np.where(raw['Regionname'] == region, 1, 0)
    
print(X.columns)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# Index(['Rooms', 'Distance', 'Lattitude', 'Longtitude', 'Bedroom2', 'Bathroom',
#        'Car', 'BuildingArea', 'Northern Metropolitan', 'Western Metropolitan',
# ...

# %%
#Principal Component Analysis
pca = PCA(n_components = 4)
colin_feat = X[['Bedroom2', 'Bathroom','Car', 'BuildingArea']]

pca.fit(colin_feat)

pca.
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-23-ed79d7d23fb7> in <module>
#       5 pca.fit(colin_feat)
#       6
# ----> 7 print(len(pca.get_params(colin_feat)))
#
# /usr/local/lib/python3.6/dist-packages/sklearn/base.py in get_params(self, deep)
#     183         for key in self._get_param_names():
#     184             value = getattr(self, key, None)
# --> 185             if deep and hasattr(value, 'get_params'):
#     186                 deep_items = value.get_params().items()
#     187                 out.update((key + '__' + k, val) for k, val in deep_items)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1476         raise ValueError("The truth value of a {0} is ambiguous. "
#    1477                          "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
# ...

# %%
#Feature Validation
sns.heatmap(data.corr())

# %%
mvr = linear_model.LinearRegression()
#ridge = linear_model.Ridge()
cross_val_score(mvr, X, Y, cv = 5)
# Out:
# array([0.55978195, 0.53564781, 0.55152708, 0.50638934, 0.5810366 ])
